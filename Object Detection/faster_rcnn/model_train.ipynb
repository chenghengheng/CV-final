# %%
from __future__ import  absolute_import
import os

import ipdb
import matplotlib
from tqdm import tqdm
import torch

from utils.config import opt
from data.dataset import Dataset, TestDataset, inverse_normalize
from model import FasterRCNNVGG16
from torch.utils import data as data_
from trainer import FasterRCNNTrainer
from utils import array_tool as at
from utils.vis_tool import visdom_bbox
from utils.eval_tool import eval_detection_voc

import resource
from torch.utils.tensorboard import SummaryWriter


rlimit = resource.getrlimit(resource.RLIMIT_NOFILE)
resource.setrlimit(resource.RLIMIT_NOFILE, (20480, rlimit[1]))

matplotlib.use('agg')


def eval(dataloader, faster_rcnn, trainer, test_num=10000):
    pred_bboxes, pred_labels, pred_scores = list(), list(), list()
    gt_bboxes, gt_labels, gt_difficults = list(), list(), list()
    loss = 0
    for ii, (imgs, sizes, gt_bboxes_, gt_labels_, gt_difficults_) in tqdm(enumerate(dataloader)):
        
        '''
        scale = at.scalar(torch.tensor([1], dtype=torch.float64))
        loss += sum(trainer.test_step(imgs.cuda().float(), gt_bboxes_.cuda(), gt_labels_.cuda(), scale))
        
        '''
        sizes = [sizes[0][0].item(), sizes[1][0].item()]
        pred_bboxes_, pred_labels_, pred_scores_ = faster_rcnn.predict(imgs, [sizes])
        gt_bboxes += list(gt_bboxes_.numpy())
        gt_labels += list(gt_labels_.numpy())
        gt_difficults += list(gt_difficults_.numpy())
        pred_bboxes += pred_bboxes_
        pred_labels += pred_labels_
        pred_scores += pred_scores_
        
        
        if ii == test_num: break

    
    result = eval_detection_voc(
        pred_bboxes, pred_labels, pred_scores,
        gt_bboxes, gt_labels, gt_difficults,
        use_07_metric=True)
    
    
    return result


def train(**kwargs):
    opt._parse(kwargs)

    writer = SummaryWriter("faster")
    dataset = Dataset(opt)
    print('load data')
    dataloader = data_.DataLoader(dataset, \
                                  batch_size=1, \
                                  shuffle=True, \
                                  # pin_memory=True,
                                  num_workers=opt.num_workers)
    testset = TestDataset(opt)
    test_dataloader = data_.DataLoader(testset,
                                       batch_size=1,
                                       num_workers=opt.test_num_workers,
                                       shuffle=False, \
                                       pin_memory=True
                                       )
    faster_rcnn = FasterRCNNVGG16()
    print('model construct completed')
    trainer = FasterRCNNTrainer(faster_rcnn).cuda()
    if opt.load_path:
        trainer.load(opt.load_path)
        print('load pretrained model from %s' % opt.load_path)
    trainer.vis.text(dataset.db.label_names, win='labels')
    
    best_map = 0
    lr_ = opt.lr
    
    for epoch in range(opt.epoch):
        print("epoch:",epoch+1)
        trainer.reset_meters()
        for ii, (img, bbox_, label_, scale) in tqdm(enumerate(dataloader)):
            scale = at.scalar(scale)
            img, bbox, label = img.cuda().float(), bbox_.cuda(), label_.cuda()
            trainer.train_step(img, bbox, label, scale, epoch, ii, writer)

            if (ii + 1) % opt.plot_every == 0:
                if os.path.exists(opt.debug_file):
                    ipdb.set_trace()

        torch.cuda.empty_cache()
        eval_result = eval(test_dataloader, faster_rcnn, trainer, test_num=opt.test_num)
        torch.cuda.empty_cache()
        #writer.add_scalars('mloss', {'test': loss_test}, epoch+1)
        writer.add_scalars('map', {'test': eval_result['map']}, epoch+1)

        if eval_result['map'] > best_map:
            best_map = eval_result['map']
            best_path = trainer.save(best_map=best_map)
        save = trainer.save(epoch=epoch)
        
        if epoch == 14:
            trainer.faster_rcnn.scale_lr(opt.lr_decay)
            lr_ = lr_ * opt.lr_decay
        
        writer.flush()
    writer.close()

# %%
if __name__ == '__main__':
    train()
# Out:
# ======user config========
# {'caffe_pretrain': False,
#  'caffe_pretrain_path': None,
#  'data': 'voc',
#  'debug_file': '/tmp/debugf',
#  'env': 'fasterrcnn-caffe',
#  'epoch': 30,
#  'load_path': None,
#  'lr': 0.001,
#  'lr_decay': 0.1,
#  'max_size': 1000,
#  'min_size': 600,
#  'num_workers': 8,
#  'plot_every': 100,
#  'port': 8097,
#  'pretrained_model': 'vgg16',
#  'roi_sigma': 1.0,
#  'rpn_sigma': 3.0,
#  'test_num': 10000,
#  'test_num_workers': 8,
#  'use_adam': False,
#  'use_chainer': False,
#  'use_drop': False,
#  'voc_data_dir': '/root/simple/VOCdevkit/VOC2007/',
#  'weight_decay': 0.0005}
# ==========end============
# load data
# Setting up a new session...
# Without the incoming socket you cannot receive events from the server or register event handlers to your Visdom client.
# model construct completed
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-5021961d5ada> in <module>
#       1 if __name__ == '__main__':
# ----> 2     train()
#
# <ipython-input-1-5c6176e5c493> in train(**kwargs)
#      85     trainer.vis.text(dataset.db.label_names, win='labels')
#      86
# ---> 87     trainer.load('/root/model.pth')
#      88
#      89     best_map = 0
#
# ~/simple/trainer.py in load(self, path, load_optimizer, parse_opt)
#     217
#     218     def load(self, path, load_optimizer=True, parse_opt=False, ):
# --> 219         state_dict = t.load(path)
#     220         if 'model' in state_dict:
#     221             self.faster_rcnn.load_state_dict(state_dict['model'])
#
# /usr/local/miniconda3/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     606                     return torch.jit.load(opened_file)
#     607                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 608         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     609
#     610
#
# /usr/local/miniconda3/lib/python3.6/site-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     777     magic_number = pickle_module.load(f, **pickle_load_args)
#     778     if magic_number != MAGIC_NUMBER:
# --> 779         raise RuntimeError("Invalid magic number; corrupt file?")
#     780     protocol_version = pickle_module.load(f, **pickle_load_args)
#     781     if protocol_version != PROTOCOL_VERSION:
#
# RuntimeError: Invalid magic number; corrupt file?
